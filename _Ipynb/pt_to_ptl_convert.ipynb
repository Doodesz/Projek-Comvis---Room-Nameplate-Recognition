# %%
# !pip3 install torch torchvision --index-url https://download.pytorch.org/whl/cu126
# !pip install ultralytics
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# ...

# %%
from ultralytics import YOLO

# Load your original trained YOLO model
model = YOLO('my_model.pt') # <-- Make sure this is your .pt file name

# --- THIS IS THE FINAL FIX ---
# We are explicitly telling the exporter the image size will be 640x640.
model.export(format='torchscript', imgsz=640, optimize=True)


print("\n--- EXPORT COMPLETE ---")
print("This is the one! A new file ending in '.torchscript' was just created.")
print("Please RENAME this new file to 'my_model.ptl' and copy it to your Android app's assets folder!")
# Out:
# Ultralytics 8.3.200  Python-3.13.3 torch-2.8.0+cpu CPU (11th Gen Intel Core i5-11400H @ 2.70GHz)
# YOLO11s summary (fused): 100 layers, 9,416,283 parameters, 0 gradients, 21.3 GFLOPs
#
# PyTorch: starting from 'my_model.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 13, 8400) (18.3 MB)
#
# TorchScript: starting export with torch 2.8.0+cpu...
# TorchScript: optimizing for mobile...
# TorchScript: export success  3.7s, saved as 'my_model.torchscript' (36.1 MB)
#
# Export complete (4.3s)
# Results saved to D:\Rizqy\Kuliah\Sem 5\Computer Vision\Projek Comvis - Room Nameplate Recognition\_Ipynb
# Predict:         yolo predict task=detect model=my_model.torchscript imgsz=640
# Validate:        yolo val task=detect model=my_model.torchscript imgsz=640 data=/content/data.yaml
# Visualize:       https://netron.app
#
# --- EXPORT COMPLETE ---
# This is the one! A new file ending in '.torchscript' was just created.
# ...
